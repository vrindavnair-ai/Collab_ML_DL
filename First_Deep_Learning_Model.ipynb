# %% [markdown]
# <a href="https://colab.research.google.com/github/vrindavnair-ai/Collab_ML_DL/blob/main/First_Deep_Learning_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # First Deep Learning Model

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_circles

# %%
X, y = make_circles(n_samples=1000,
                    noise=0.1,
                    factor=0.2,
                    random_state=0)

# %%
X
# Out:
# array([[ 0.24265541,  0.0383196 ],
#        [ 0.04433036, -0.05667334],
#        [-0.78677748, -0.75718576],
#        ...,
#        [ 0.0161236 , -0.00548034],
#        [ 0.20624715,  0.09769677],
#        [-0.19186631,  0.08916672]])

# %%
X.shape
# Out:
# (1000, 2)

# %%
plt.figure(figsize=(5, 5))
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses")
# Out:
# Text(0.5, 1.0, 'Blue circles and Red crosses')

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD

# %%
model = Sequential()

# %%
model.add(Dense(4, input_shape=(2,), activation='softmax'))

# %%
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(SGD(learning_rate=0.5), 'binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.7003 - accuracy: 0.4860
# Epoch 2/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6912 - accuracy: 0.5600
# Epoch 3/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6843 - accuracy: 0.5580
# Epoch 4/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6766 - accuracy: 0.6380
# Epoch 5/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6568 - accuracy: 0.7140
# Epoch 6/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6283 - accuracy: 0.8020
# Epoch 7/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5836 - accuracy: 0.8380
# Epoch 8/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5265 - accuracy: 0.8400
# Epoch 9/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4735 - accuracy: 0.8530
# Epoch 10/100
# ...

# %%
hticks = np.linspace(-1.5, 1.5, 101)
vticks = np.linspace(-1.5, 1.5, 101)
aa, bb = np.meshgrid(hticks, vticks)
ab = np.c_[aa.ravel(), bb.ravel()]
c = model.predict(ab)
cc = c.reshape(aa.shape)

# %%
plt.figure(figsize=(5, 5))
plt.contourf(aa, bb, cc, cmap='bwr', alpha=0.2)
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses")
# Out:
# Text(0.5, 1.0, 'Blue circles and Red crosses')
